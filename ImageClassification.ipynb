# %%
import numpy as np
import keras
from keras import backend as k
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from tensorflow.keras.optimizers import Adam

from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization


from keras.layers.convolutional import *
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
# %matplotlib inline

# %%
train_path = 'XRays/train'
valid_path = 'XRays/valid'
test_path = 'XRays/test'

# %%
train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(224,224), classes=['dog','cat','monkey','cow'], batch_size=10)
valid_batches = ImageDataGenerator().flow_from_directory(valid_path, target_size=(224,224), classes=['dog','cat','monkey','cow'], batch_size=4)
test_batches = ImageDataGenerator().flow_from_directory(test_path, target_size=(224,224), classes=['dog','cat','monkey','cow'], batch_size=4)
# Out:
# Found 19 images belonging to 4 classes.
# Found 2 images belonging to 4 classes.
# Found 21 images belonging to 4 classes.

# %%
# plots images with labels within jupyter notebook
def plots(ims, figsize=(20,6), rows=1, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
            ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i], interpolation=None if interp else 'none')

# %%
imgs, labels = next(train_batches)

# %%
plots(imgs, titles=labels)
# Out:
# c:\python39\lib\site-packages\matplotlib\text.py:1215: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
train_batches.class_indices
# Out:
# {'dog': 0, 'cat': 1, 'monkey': 2, 'cow': 3}

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
vgg16_model = keras.applications.vgg16.VGG16()

# %%
vgg16_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
type(vgg16_model)
# Out:
# keras.engine.functional.Functional

# %%
model = Sequential()
for i in vgg16_model.layers:
    model.add(i)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers.pop()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in model.layers:
    layer.trainable = False

# %%
model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
#  dense (Dense)               (None, 4)                 4004
#
# =================================================================
# Total params: 138,361,548
# Trainable params: 4,004
# Non-trainable params: 138,357,544
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.07), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\kucaa\AppData\Roaming\Python\Python39\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.fit_generator(train_batches, steps_per_epoch=1, 
                    validation_data=valid_batches, validation_steps=1, epochs=30, verbose=2)
# Out:
# Epoch 1/30
# C:\Users\kucaa\AppData\Local\Temp/ipykernel_20296/3959545254.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_batches, steps_per_epoch=1,
# 1/1 - 2s - loss: 1.3959 - accuracy: 0.1000 - val_loss: 1.3503 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 2/30
# 1/1 - 1s - loss: 1.3175 - accuracy: 0.6000 - val_loss: 1.3028 - val_accuracy: 0.5000 - 1s/epoch - 1s/step
# Epoch 3/30
# 1/1 - 2s - loss: 1.2453 - accuracy: 0.7000 - val_loss: 1.2640 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 4/30
# 1/1 - 1s - loss: 1.2315 - accuracy: 0.6667 - val_loss: 1.2481 - val_accuracy: 0.5000 - 1s/epoch - 1s/step
# Epoch 5/30
# 1/1 - 1s - loss: 1.0538 - accuracy: 0.8889 - val_loss: 1.2396 - val_accuracy: 0.5000 - 1s/epoch - 1s/step
# Epoch 6/30
# 1/1 - 1s - loss: 1.1505 - accuracy: 0.5556 - val_loss: 1.2189 - val_accuracy: 0.5000 - 1s/epoch - 1s/step
# Epoch 7/30
# 1/1 - 1s - loss: 1.1211 - accuracy: 0.5556 - val_loss: 1.2010 - val_accuracy: 0.5000 - 1s/epoch - 1s/step
# Epoch 8/30
# 1/1 - 2s - loss: 0.8503 - accuracy: 0.9000 - val_loss: 1.1917 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 9/30
# 1/1 - 2s - loss: 1.0448 - accuracy: 0.6000 - val_loss: 1.1853 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 10/30
# 1/1 - 1s - loss: 1.0726 - accuracy: 0.5556 - val_loss: 1.1802 - val_accuracy: 0.5000 - 1s/epoch - 1s/step
# Epoch 11/30
# 1/1 - 2s - loss: 1.0197 - accuracy: 0.6000 - val_loss: 1.1732 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 12/30
# 1/1 - 1s - loss: 0.9089 - accuracy: 0.7778 - val_loss: 1.1741 - val_accuracy: 0.5000 - 1s/epoch - 1s/step
# Epoch 13/30
# 1/1 - 2s - loss: 0.8377 - accuracy: 0.7000 - val_loss: 1.1771 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 14/30
# 1/1 - 2s - loss: 0.8266 - accuracy: 0.6667 - val_loss: 1.1805 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 15/30
# 1/1 - 2s - loss: 0.8388 - accuracy: 0.7000 - val_loss: 1.1857 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 16/30
# 1/1 - 2s - loss: 0.9060 - accuracy: 0.6000 - val_loss: 1.1939 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 17/30
# 1/1 - 2s - loss: 0.9772 - accuracy: 0.5000 - val_loss: 1.1980 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 18/30
# 1/1 - 2s - loss: 0.7370 - accuracy: 0.7000 - val_loss: 1.2088 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 19/30
# 1/1 - 2s - loss: 0.5542 - accuracy: 0.9000 - val_loss: 1.2267 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 20/30
# 1/1 - 2s - loss: 0.7439 - accuracy: 0.6667 - val_loss: 1.2398 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 21/30
# 1/1 - 2s - loss: 0.6375 - accuracy: 0.7778 - val_loss: 1.2566 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 22/30
# 1/1 - 2s - loss: 0.5436 - accuracy: 0.8889 - val_loss: 1.2797 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 23/30
# 1/1 - 2s - loss: 0.6591 - accuracy: 0.8000 - val_loss: 1.3010 - val_accuracy: 0.5000 - 2s/epoch - 2s/step
# Epoch 24/30

# %%
model.save_weights('model_weights.h5')

# %%
test_imgs, test_labels = next(test_batches)
plots(test_imgs, titles=test_labels)
print(test_labels)
predictions = model.predict_on_batch(np.array(test_imgs))
print(predictions)
test_labels = np.array(test_labels.argmax(axis=1))
predictions = np.array(predictions.argmax(axis=1))

# %%
print(test_labels)
print(predictions)

# %%
cm = confusion_matrix(test_labels, predictions)

# %%
cm_plot_labels = ['No Disease in Chest','Possible Disease in Chest','No Disease in Brain','Possible Disease in Brain']
if 0 not in test_labels and 0 not in predictions:
    cm_plot_labels.remove('No disease in chest')
if 1 not in test_labels and 1 not in predictions:
    cm_plot_labels.remove('Possible disease in Chest')
if 2 not in test_labels and 2 not in predictions:
    cm_plot_labels.remove('No disease in Brain')
if 3 not in test_labels and 3 not in predictions:
    cm_plot_labels.remove('Possible disease in brain')

# %%
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix')

# %%
cm = np.array([[1401,    0],[1112, 0]])

plt.imshow(cm, cmap=plt.cm.Blues)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.xticks([], [])
plt.yticks([], [])
plt.title('Confusion matrix ')
plt.colorbar()
plt.show()
